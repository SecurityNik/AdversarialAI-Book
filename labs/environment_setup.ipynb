# %% [markdown]
# <img style="max-width:20em; height:auto;" src="../graphics/A-Little-Book-on-Adversarial-AI-Cover.png"/>

# %% [markdown]
# Author: Nik Alleyne
# Author Blog: https://www.securitynik.com
# Author GitHub: github.com/securitynik
#
# Author Other Books: [
#
#             "https://www.amazon.ca/Learning-Practicing-Leveraging-Practical-Detection/dp/1731254458/",
#
#             "https://www.amazon.ca/Learning-Practicing-Mastering-Network-Forensics/dp/1775383024/"
#         ]
#
#
# This notebook ***(environment_setup.ipynb)*** is part of the series of notebooks From ***A Little Book on Adversarial AI***  A free ebook released by Nik Alleyne

# %% [markdown]
# ### Environment Setup
#
# **Note** I assume you have completed the install of WSL, Miniconda and VSCode as directed in the book.
#
# This notebook is focused on installing the needed libraries and setting up your Conda Environment. It is meant to ease your pain of finding the appropriate libraries and more importantly, the correction version. I've pinned the versions where needed so you have less chances of not being able to run these notebooks successfully.
#
# I assume you have installed either Windows Subsystem For Linux (WSL2) or you have a Linux device or maybe a Mac. With those in place, your first step is to install either Anaconda or Miniconda. I use Miniconda.
#
# I wrote these notebooks in VSCode with Miniconda:
# https://www.anaconda.com/docs/getting-started/miniconda/install#linux
#
# However, you can use Jupyter environment you feel most comfortable with.
#
# Assuming that you have installed Conda ...
#
# Let us first start by setting up our Conda environment. Open a command prompt, terminal or whatever you use for shell and type:
#
# $ **conda create --name=adversarial_ai python=3.12 --yes**
#
# With the environment created, time to activate this environment.
#
# $ **conda activate adversarial_ai**
#
# if everything worked out, you should now see something such as:
# **(adversarial_ai)** securitynik@SECURITYNIK-G14:~$
#
# Assuming you are good to go and are in the environment, let us install the first library:
# $ **pip install ipykernel --verbose --no-cache-dir**
#
# Let us know connect VSCode to this environment by selling **Select kernel** on the top right of your VSCode window. Assuming obviously, that you are using VSCode.
#
#
# If everything worked according to plan, then where you had "Select Kernel", should now have "adversarial_ai (Python 3.12.11)"
#
# Let us now install the rest of our libraries, you can install everything by running the cell below.

# %%
# Install needed libraries 
# !pip install \
    numpy==2.3.1 \
    matplotlib==3.10.3 \
    cryptography==45.0.5 \
    dotenv==0.9.9  \
    onnxruntime==1.22.1 \
    adversarial-robustness-toolbox==1.20.1 \
    IProgress==0.4  \
    tqdm==4.67.1  \
    ipywidgets==8.1.7 \
    fickling==0.1.4 \
    picklescan==0.0.26 \
    skl2onnx==1.19.1 \
    torch==2.7.1 \
    scikit-learn==1.7.0 --verbose --no-cache-dir
# Out:
# Using pip 25.1 from /home/securitynik/miniconda3/envs/adversarial_ai/lib/python3.12/site-packages/pip (python 3.12)
#   Link requires a different Python (3.12.11 not in: '>=3.7,<3.11'): https://files.pythonhosted.org/packages/3a/be/650f9c091ef71cb01d735775d554e068752d3ff63d7943b26316dc401749/numpy-1.21.2.zip (from https://pypi.org/simple/numpy/) (requires-python:>=3.7,<3.11)
#   Link requires a different Python (3.12.11 not in: '>=3.7,<3.11'): https://files.pythonhosted.org/packages/5f/d6/ad58ded26556eaeaa8c971e08b6466f17c4ac4d786cd3d800e26ce59cc01/numpy-1.21.3.zip (from https://pypi.org/simple/numpy/) (requires-python:>=3.7,<3.11)
#   Link requires a different Python (3.12.11 not in: '>=3.7,<3.11'): https://files.pythonhosted.org/packages/fb/48/b0708ebd7718a8933f0d3937513ef8ef2f4f04529f1f66ca86d873043921/numpy-1.21.4.zip (from https://pypi.org/simple/numpy/) (requires-python:>=3.7,<3.11)
# ...

# %%
# For some strange reason, I was unable to install this above with the others.
# Not a major issue
# !pip install safetensors \
    tensorflow==2.19 \
    pandas==2.3.1 \
    seaborn==0.13.2  \
    torchinfo==1.8.0  \
    torchvision==0.22.1 \
    netron==8.4.4 \
    torch_geometric==2.6.1 \
    foolbox==3.3.4 \
    torchattacks \
    onnxscript --verbose --no-cache-dir
# Out:
# Using pip 25.1 from /home/securitynik/miniconda3/envs/adversarial_ai/lib/python3.12/site-packages/pip (python 3.12)
# ...
#   Obtaining dependency information for safetensors from https://files.pythonhosted.org/packages/a6/f8/dae3421624fcc87a89d42e1898a798bc7ff72c61f38973a65d60df8f124c/safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
#   Obtaining dependency information for tensorflow==2.19 from https://files.pythonhosted.org/packages/01/12/a8ad8322a7cb2818e658a073feb2aa541d0e6a32b8e5ac838d46e0882687/tensorflow-2.19.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
#   Obtaining dependency information for pandas==2.3.1 from https://files.pythonhosted.org/packages/da/01/e383018feba0a1ead6cf5fe8728e5d767fee02f06a3d800e82c489e5daaf/pandas-2.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...

# %%
# Let us now install mlflow
# !pip install mlflow==3.1 \
pydot \
modelscan --verbose --no-cache-dir
# Out:
# Using pip 25.1 from /home/securitynik/miniconda3/envs/adversarial_ai/lib/python3.12/site-packages/pip (python 3.12)
# ...
#   Obtaining dependency information for pydot from https://files.pythonhosted.org/packages/7e/32/a7125fb28c4261a627f999d5fb4afff25b523800faed2c30979949d6facd/pydot-4.0.1-py3-none-any.whl.metadata
# ...

# %% [markdown]
# ### Additional tools
#
# Go to your command prompt and install these
#
# # Install ...
# $ sudo apt install tree ncat graphviz

# %% [markdown]
# Assuming everything went well, you are now ready to move forward with the other notebooks in this series.
#
# ### Good luck and have fun learning!
